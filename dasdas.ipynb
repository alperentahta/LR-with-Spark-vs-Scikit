# %%
import argparse
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np

import pandas as pd

parser = argparse.ArgumentParser()
#parser.add_argument("path", help="Path for result file to parse and plot")
#parser.add_argument("--log_datasize", action='store_true', default=False, help="Take a log for datasize values")
#parser.add_argument("--log_elapsedtime", action='store_true', default=False, help="Take a log for elapsedtime values")
#args = parser.parse_args()

path='result.txt'
result_df = pd.read_csv(path, sep=' - ', header=None, engine='python')
result_df.columns = ['core', 'path', 'size', 'elapsed_time']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-05e62743bd3c> in <module>
#      14
#      15 path='result.txt'
# ---> 16 result_df = pd.read_csv(path, sep=' - ', header=None, engine='python')
#      17 result_df.columns = ['core', 'path', 'size', 'elapsed_time']
#      18
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     695                     skip_blank_lines=skip_blank_lines)
#     696
# --> 697         return _read(filepath_or_buffer, kwds)
#     698
#     699     parser_f.__name__ = name
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     422
#     423     # Create the parser.
# --> 424     parser = TextFileReader(filepath_or_buffer, **kwds)
#     425
#     426     if chunksize or iterator:
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     888             self.options['has_index_names'] = kwds['has_index_names']
#     889
# --> 890         self._make_engine(self.engine)
#     891
#     892     def close(self):
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1125                                  ' "c", "python", or' ' "python-fwf")'.format(
#    1126                                      engine=engine))
# -> 1127             self._engine = klass(self.f, **self.options)
#    1128
#    1129     def _failover_to_python(self):
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2218         f, handles = _get_handle(f, mode, encoding=self.encoding,
#    2219                                  compression=self.compression,
# -> 2220                                  memory_map=self.memory_map)
#    2221         self.handles.extend(handles)
#    2222
#
# ~/anaconda3/envs/sparklr/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
# --> 427             f = open(path_or_buf, mode, errors='replace', newline="")
#     428         else:
#     429             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result.txt'

# %%
df=pd.DataFrame(data=d)
print(df)

# %%
pd.DataFrame
